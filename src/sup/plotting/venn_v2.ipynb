# %%
pip install matplotlib_venn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib_venn
#   Downloading matplotlib-venn-0.11.9.tar.gz (30 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib_venn) (3.7.1)
# Requirement already satisfied: numpy in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib_venn) (1.24.2)
# Requirement already satisfied: scipy in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib_venn) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from matplotlib->matplotlib_venn) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/polina/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib_venn) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib_venn) (1.15.0)
# Building wheels for collected packages: matplotlib_venn
#   Building wheel for matplotlib_venn (pyproject.toml) ... done
#   Created wheel for matplotlib_venn: filename=matplotlib_venn-0.11.9-py3-none-any.whl size=32999 sha256=c56351d55a8950b3cabefbbda0bd8546f6790e66fe66a67583d1a32dab04f39a
#   Stored in directory: /Users/polina/Library/Caches/pip/wheels/25/de/d4/29dfc5d4520b956df7bc54a8464ad053042918bc525e88bf66
# Successfully built matplotlib_venn
# Installing collected packages: matplotlib_venn
# Successfully installed matplotlib_venn-0.11.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
import seaborn as sns

# %%
Expedited = 310
Severe = 293
GE = 274

Expedited_Severe = 251
Expedited_GE = 199
Severe_GE = 205

Expedited_Severe_GE = 175

a = Expedited
b = Severe
c = GE

ab = Expedited_Severe
bc = Severe_GE
ca = Expedited_GE

abc = Expedited_Severe_GE

A = a - ab - ca + abc
B = b - ab - bc + abc
C = c - ca - bc + abc

AB = ab - abc
BC = bc - abc
CA = ca - abc

ABC = abc

# %%
# Expedited_Severe/Expedited * 100
Severe_GE/Severe * 100
# Out:
# 69.96587030716724

# %%
palette = sns.color_palette('Set2')

# %%
prod = (A, B, AB, C, CA, BC, ABC)
venn3(subsets = prod, 
      set_labels = ('Expedited', 'Severe', 'GE'),
      set_colors=palette[:3])
plt.show()

# %%
Standard = 118
Severe = 293
GE = 274

Standard_Severe = 41
Standard_GE = 74
Severe_GE = 205

Standard_Severe_GE = 30

a = Standard
b = Severe
c = GE

ab = Standard_Severe
bc = Severe_GE
ca = Standard_GE

abc = Standard_Severe_GE

A = a - ab - ca + abc
B = b - ab - bc + abc
C = c - ca - bc + abc

AB = ab - abc
BC = bc - abc
CA = ca - abc

ABC = abc

# %%
palette = sns.color_palette('Set2')

# %%
prod = (A, B, AB, C, CA, BC, ABC)
venn3(subsets = prod, 
      set_labels = ('Standard', 'Severe', 'GE'),
      set_colors=palette[:3])
plt.show()

# %%
Standard = 118
Non_severe = 105
No_GE = 63

Standard_Non_severe = 68
Standard_no_GE = 28
Non_severe_no_GE = 24

Intersection = 19

a = Standard
b = Non_severe
c = No_GE

ab = Standard_Non_severe
bc = Non_severe_no_GE
ca = Standard_no_GE

abc = Intersection

A = a - ab - ca + abc
B = b - ab - bc + abc
C = c - ca - bc + abc

AB = ab - abc
BC = bc - abc
CA = ca - abc

ABC = abc

# %%
# Standard_Non_severe/Standard * 100
# Standard_no_GE/Standard * 100
# Standard_no_GE/No_GE * 100
Non_severe_no_GE/No_GE * 100
# Out:
# 38.095238095238095

# %%
palette = sns.color_palette('Set2')

# %%
prod = (A, B, AB, C, CA, BC, ABC)
venn3(subsets = prod, 
      set_labels = ('Standard', 'Non_severe', 'No_GE'),
      set_colors=(palette[1],palette[2],palette[3]) )
plt.show()

# %%
ab
# Out:
# 68

# %%
Standard = 118
Non_severe = 105
GE = 274

Standard_Non_severe = 68
Standard_GE = 74
Non_severe_GE = 56

Intersection = 39

a = Standard
b = Non_severe
c = GE

ab = Standard_Non_severe
bc = Non_severe_GE
ca = Standard_GE

abc = Intersection

A = a - ab - ca + abc
B = b - ab - bc + abc
C = c - ca - bc + abc

AB = ab - abc
BC = bc - abc
CA = ca - abc

ABC = abc

assert(A + B)

print(A, B, C)
print(AB, BC, CA)
print(ABC)
# Out:
# 15 20 183
# 29 17 35
# 39

# %%
palette = sns.color_palette()

# %%
test = (1, 2, 3, 4, 5, 6, 7)
prod = (A, B, AB, C, CA, BC, ABC)
# A B AB C AC BC ABC
pipka = venn3(subsets = prod, #(A, B, C, AB, BC, CA, ABC), 
      set_labels = ('Standard', 'Non_severe', 'GE'),
      set_colors=palette[:3])
plt.show(pipka)
